# %% [markdown]
# # Neural Network Fundamentals
# ## Basic NN Components

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

class LinearLayer(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.weights = nn.Parameter(torch.randn(input_dim, output_dim)*0.01)
        self.bias = nn.Parameter(torch.zeros(output_dim))

    def forward(self, x):
        return torch.matmul(x, self.weights) + self.bias
    

def gelu(x):
    '''
    gaussian error linear unit
    use torch.nn.GELU() or torch.nn.functional.gelu(x) in production
    '''
    return 0.5 * x * (1.0 + torch.tanh(math.sqrt(2.0 / math.pi) * (x + 0.044715 * x.pow(3))))

# %%
import matplotlib.pyplot as plt



# ensure x and y are tensors / numpy for plotting
x = torch.arange(0, 5, dtype=torch.float32)
y = gelu(x).detach()

plt.figure(figsize=(10, 6))
plt.plot(x.numpy(), y, marker='o')
plt.plot(x, x, marker='*')
plt.title('GELU activation')
plt.xlabel('x')
plt.ylabel('gelu(x)')
plt.grid(True)
plt.show()
